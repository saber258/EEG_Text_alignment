# %%
import pandas as pd
import os
import pathlib

# %%
# !ls
# Out:
# README.md            json                 transcripts_csv
# concat_p             preprocess_csv.ipynb transcripts_csv_2
# emotion_annotations  test.csv             transcripts_csv_3

# %%
df_p1_p2 = pd.read_csv('transcripts_csv/p1.p2.m4a-20220330163422.csv')
df_p1_p2
# Out:
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#      results/alternatives/0/words/0/endTime  \
# 0                                    2.400s
# 1                                        3s
# 2                                    3.300s
# 3                                    3.400s
# 4                                    3.500s
# ...                                     ...
# 3448                               852.700s
# 3449                               851.600s
# 3450                                   852s
# 3451                               852.400s
# 3452                               852.600s
#
#      results/alternatives/0/words/0/startTime  \
# 0                                      2.300s
# 1                                      2.400s
# 2                                          3s
# 3                                      3.300s
# 4                                      3.400s
# ...                                       ...
# 3448                                 852.400s
# 3449                                 851.500s
# 3450                                 851.600s
# 3451                                 852.100s
# 3452                                 852.400s
#
#      results/alternatives/0/words/0/word results/channelTag  \
# 0                                    all                  2
# 1                                  right                  2
# 2                                  first                  2
# 3                                    one                  2
# 4                                    the                  2
# ...                                  ...                ...
# 3448                                 now                  0
# 3449                              Sprint                  0
# 3450                                  is                  0
# 3451                                over                  0
# 3452                                 now                  0
#
#      results/languageCode results/resultEndTime
# 0                   en-us            25.888572s
# 1                   en-us            25.888572s
# 2                   en-us            25.888572s
# 3                   en-us            25.888572s
# 4                   en-us            25.888572s
# ...                   ...                   ...
# 3448                en-us           853.982100s
# 3449                en-us           854.002141s
# 3450                en-us           854.002141s
# 3451                en-us           854.002141s
# 3452                en-us           854.002141s
#
# [3453 rows x 9 columns]

# %%
df_p1_self = pd.read_csv('emotion_annotations/self_annotations/P1.self.csv')
df_p1_self
# Out:
#      seconds  arousal  valence  cheerful  happy  angry  nervous  sad boredom  \
# 0          5        1        2         1      1      1        1    1       x
# 1         10        1        2         1      1      1        1    1       x
# 2         15        2        2         1      1      1        1    1     NaN
# 3         20        2        3         1      1      1        1    1     NaN
# 4         25        2        3         1      1      1        1    1     NaN
# ..       ...      ...      ...       ...    ...    ...      ...  ...     ...
# 176      885        3        3         1      1      1        1    1     NaN
# 177      890        3        3         1      1      1        1    1     NaN
# 178      895        4        4         3      3      1        1    1     NaN
# 179      900        3        3         2      2      1        1    1     NaN
# 180      905        2        3         1      1      1        1    1     NaN
#
#      confusion  ... surprise none_1  confrustion contempt dejection  disgust  \
# 0          NaN  ...      NaN    NaN          NaN      NaN       NaN      NaN
# 1          NaN  ...      NaN    NaN          NaN      NaN       NaN      NaN
# 2          NaN  ...      NaN      x          NaN      NaN       NaN      NaN
# 3          NaN  ...      NaN      x          NaN      NaN       NaN      NaN
# 4          NaN  ...      NaN      x          NaN      NaN       NaN      NaN
# ..         ...  ...      ...    ...          ...      ...       ...      ...
# 176        NaN  ...      NaN    NaN          NaN      NaN       NaN      NaN
# 177        NaN  ...      NaN    NaN          NaN      NaN       NaN      NaN
# 178        NaN  ...      NaN    NaN          NaN      NaN       NaN      NaN
# 179        NaN  ...      NaN    NaN          NaN      NaN       NaN      NaN
# 180        NaN  ...      NaN      x          NaN      NaN       NaN      NaN
#
#      eureka  pride  sorrow  none_2
# 0       NaN    NaN     NaN       x
# 1       NaN    NaN     NaN       x
# 2       NaN    NaN     NaN       x
# 3       NaN    NaN     NaN       x
# 4       NaN    NaN     NaN       x
# ..      ...    ...     ...     ...
# 176     NaN    NaN     NaN       x
# 177     NaN    NaN     NaN       x
# 178     NaN    NaN     NaN       x
# 179     NaN    NaN     NaN       x
# 180     NaN    NaN     NaN       x
#
# [181 rows x 23 columns]

# %%
df_p2_self = pd.read_csv('emotion_annotations/self_annotations/P2.self.csv')
df_p2_self
# Out:
#      seconds  arousal  valence  cheerful  happy  angry  nervous  sad boredom  \
# 0          5        4        3         2      2      1        3    1     NaN
# 1         10        4        3         2      2      1        3    1     NaN
# 2         15        4        3         2      2      1        3    1     NaN
# 3         20        4        3         2      2      1        3    1     NaN
# 4         25        4        3         2      2      1        3    1     NaN
# ..       ...      ...      ...       ...    ...    ...      ...  ...     ...
# 175      880        2        4         2      3      1        1    1     NaN
# 176      885        2        3         2      3      1        1    1     NaN
# 177      890        2        3         2      4      1        1    1     NaN
# 178      895        2        3         2      4      1        2    1     NaN
# 179      900        2        3         2      4      1        2    1     NaN
#
#     confusion  ... surprise none_1 confrustion  contempt dejection disgust  \
# 0         NaN  ...      NaN    NaN         NaN       NaN       NaN     NaN
# 1         NaN  ...      NaN    NaN         NaN       NaN       NaN     NaN
# 2         NaN  ...      NaN    NaN         NaN       NaN       NaN     NaN
# 3         NaN  ...      NaN    NaN         NaN       NaN       NaN     NaN
# 4         NaN  ...      NaN    NaN         NaN       NaN       NaN     NaN
# ..        ...  ...      ...    ...         ...       ...       ...     ...
# 175       NaN  ...      NaN      x         NaN       NaN       NaN     NaN
# 176       NaN  ...      NaN      x         NaN       NaN       NaN     NaN
# 177       NaN  ...      NaN    NaN         NaN       NaN       NaN     NaN
# 178       NaN  ...      NaN      x         NaN       NaN       NaN     NaN
# 179       NaN  ...      NaN      x         NaN       NaN       NaN     NaN
#
#      eureka  pride  sorrow  none_2
# 0       NaN    NaN     NaN       x
# 1       NaN    NaN     NaN       x
# 2       NaN    NaN     NaN       x
# 3       NaN    NaN     NaN       x
# 4       NaN    NaN     NaN       x
# ..      ...    ...     ...     ...
# 175     NaN    NaN     NaN       x
# 176     NaN    NaN     NaN       x
# 177     NaN    NaN     NaN       x
# 178     NaN    NaN     NaN       x
# 179     NaN    NaN     NaN       x
#
# [180 rows x 23 columns]

# %%
df_p1_p2_self = pd.concat([df_p1_self, df_p2_self], axis=1)
df_p1_p2_self.to_csv("p31_p32_self.csv", sep=',', index=False)

# %%
test = pd.read_csv('test.csv')
test
# Out:
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#      results/alternatives/0/words/0/endTime  \
# 0                                    2.400s
# 1                                        3s
# 2                                    3.300s
# 3                                    3.400s
# 4                                    3.500s
# ...                                     ...
# 3448                               852.700s
# 3449                               851.600s
# 3450                                   852s
# 3451                               852.400s
# 3452                               852.600s
#
#      results/alternatives/0/words/0/startTime  \
# 0                                      2.300s
# 1                                      2.400s
# 2                                          3s
# 3                                      3.300s
# 4                                      3.400s
# ...                                       ...
# 3448                                 852.400s
# 3449                                 851.500s
# 3450                                 851.600s
# 3451                                 852.100s
# 3452                                 852.400s
#
#      results/alternatives/0/words/0/word results/channelTag  \
# 0                                    all                  2
# 1                                  right                  2
# 2                                  first                  2
# 3                                    one                  2
# 4                                    the                  2
# ...                                  ...                ...
# 3448                                 now                  0
# 3449                              Sprint                  0
# 3450                                  is                  0
# 3451                                over                  0
# 3452                                 now                  0
#
#      results/languageCode results/resultEndTime  seconds  ...  surprise.1  \
# 0                   en-us            25.888572s      5.0  ...         NaN
# 1                   en-us            25.888572s     10.0  ...         NaN
# 2                   en-us            25.888572s     15.0  ...         NaN
# 3                   en-us            25.888572s     20.0  ...         NaN
# 4                   en-us            25.888572s     25.0  ...         NaN
# ...                   ...                   ...      ...  ...         ...
# 3448                en-us           853.982100s      NaN  ...         NaN
# 3449                en-us           854.002141s      NaN  ...         NaN
# 3450                en-us           854.002141s      NaN  ...         NaN
# 3451                en-us           854.002141s      NaN  ...         NaN
# 3452                en-us           854.002141s      NaN  ...         NaN
#
#       none_1.1  confrustion.1  contempt.1  dejection.1  disgust.1  eureka.1  \
# 0          NaN            NaN         NaN          NaN        NaN       NaN
# 1          NaN            NaN         NaN          NaN        NaN       NaN
# 2          NaN            NaN         NaN          NaN        NaN       NaN
# 3          NaN            NaN         NaN          NaN        NaN       NaN
# 4          NaN            NaN         NaN          NaN        NaN       NaN
# ...        ...            ...         ...          ...        ...       ...
# 3448       NaN            NaN         NaN          NaN        NaN       NaN
# 3449       NaN            NaN         NaN          NaN        NaN       NaN
# 3450       NaN            NaN         NaN          NaN        NaN       NaN
# 3451       NaN            NaN         NaN          NaN        NaN       NaN
# 3452       NaN            NaN         NaN          NaN        NaN       NaN
#
#      pride.1  sorrow.1 none_2.1
# 0        NaN       NaN        x
# 1        NaN       NaN        x
# 2        NaN       NaN        x
# 3        NaN       NaN        x
# 4        NaN       NaN        x
# ...      ...       ...      ...
# 3448     NaN       NaN      NaN
# 3449     NaN       NaN      NaN
# 3450     NaN       NaN      NaN
# 3451     NaN       NaN      NaN
# 3452     NaN       NaN      NaN
#
# [3453 rows x 55 columns]

# %%
print(test['results/alternatives/0/confidence'])
# Out:
# 0       0.765099
# 1       0.765099
# 2       0.765099
# 3       0.765099
# 4       0.765099
#           ...
# 3448    0.774450
# 3449    0.481978
# 3450    0.481978
# 3451    0.481978
# 3452    0.481978
# Name: results/alternatives/0/confidence, Length: 3453, dtype: float64

# %%
# !ls
# Out:
# README.md            json                 transcripts_csv_2
# concat_p             preprocess_csv.ipynb transcripts_csv_3
# concat_p_transcript  test.csv
# emotion_annotations  transcripts_csv

# %%
os.getcwd()
# Out:
# '/Users/williamhan/Desktop/GitHub/CMUSAIL'

# %%
os.chdir('../')

# %%
transcripts_csv_3 = 'transcripts_csv_3'
concat_p = 'concat_p'

csv_num = 1

    
    
for csv in sorted(os.listdir(transcripts_csv_3)):

    if '.csv' in csv:

        os.chdir(transcripts_csv_3)

        read = pd.read_csv(csv)

        os.chdir('../')

                
        
    for csv_1 in sorted(concat_p):

        #os.chdir('concat_p')

        if '.csv' in csv_1:

            os.chdir(concat_p)

            read1 = pd.read_csv(csv_1)

            os.chdir('../')

            

            #os.chdir('../')

        df = pd.concat([read, read1], axis=1)
        


        os.chdir('concat_p_transcript')

        df.to_csv(f'p{csv_num}.csv', sep=',', index=False)


        csv_num += 2

        os.chdir('../')
        
        break

# %%
# !ls
# Out:
# README.md            json                 transcripts_csv_2
# concat_p             preprocess_csv.ipynb transcripts_csv_3
# concat_p_transcript  test.csv
# emotion_annotations  transcripts_csv

# %%
csv_num = 1
for i in sorted(os.listdir('transcripts_csv_3')):

    if '.csv' in i:

        os.chdir('transcripts_csv_3')

        read = pd.read_csv(i)
        
        os.chdir('../')

        #print(read)


    for j in sorted(os.listdir('concat_p')):

        if '.csv' in j:

            os.chdir('concat_p')

            read1 = pd.read_csv(j)

            os.chdir('../')

            #print(read1)

            #break

        for col in read['reult/alternative/0/word/0/tartTime']:
            
            

            col1 = read1.iloc[:, 0]

            col2 = read1.iloc[:,23]

            while (col < col1):

                new_df = read1.iloc[:, 0:23]

                new2_df = read1.iloc[:, 23:]

                for i in read['results/channelTag']:

                    if i == 0:

                        pass

                    elif i < i.cummax():

                        df = pd.concat([read, new_df], axis = 1)

                    elif i == i.cummax():
                        df = pd.merge(df, new2_df, how = 'outer' )
                    else:
                        pass
                    
        os.chdir('concat_p_transcript')             
        df.to_csv(f'p{csv_num}.csv', sep=',', index=False)
        csv_num += 2
        
        os.chdir('../')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reult/alternative/0/word/0/tartTime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/70/s03t_xm53wq9db1vxd6l5d8c0000gn/T/ipykernel_12512/1297043826.py in <module>
#      27             #break
#      28
# ---> 29         for col in read['reult/alternative/0/word/0/tartTime']:
#      30
#      31
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'reult/alternative/0/word/0/tartTime'

# %%
read['result/alternative/0/word/0/startTime'].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'result/alternative/0/word/0/startTime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/70/s03t_xm53wq9db1vxd6l5d8c0000gn/T/ipykernel_12512/138332718.py in <module>
# ----> 1 read['result/alternative/0/word/0/startTime'].dtype
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'result/alternative/0/word/0/startTime'

# %%
# !ls
# Out:
# README.md            json                 transcripts_csv_2
# concat_p             preprocess_csv.ipynb transcripts_csv_3
# concat_p_transcript  test.csv
# emotion_annotations  transcripts_csv

# %%
df = pd.read_csv('transcripts_csv_3/p1.p2.m4a-20220330163422.csv')

# %%
df['reult/alternative/0/word/0/tartTime'].dtype
# Out:
# dtype('float64')
