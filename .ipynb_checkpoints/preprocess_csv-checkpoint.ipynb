# %%
import pandas as pd
import os
import pathlib

# %%
# !ls

# %%
df_p1_p2 = pd.read_csv('transcripts_csv/p1.p2.m4a-20220330163422.csv')
df_p1_p2

# %%
df_p1_self = pd.read_csv('emotion_annotations/self_annotations/P1.self.csv')
df_p1_self

# %%
df_p2_self = pd.read_csv('emotion_annotations/self_annotations/P2.self.csv')
df_p2_self

# %%
df_p1_p2_self = pd.concat([df_p1_self, df_p2_self], axis=1)
df_p1_p2_self.to_csv("p31_p32_self.csv", sep=',', index=False)

# %%
test = pd.read_csv('test.csv')
test

# %%
print(test['results/alternatives/0/confidence'])

# %%
# !ls

# %%
os.getcwd()

# %%
os.chdir('../')

# %%
transcripts_csv_3 = 'transcripts_csv_3'
concat_p = 'concat_p'

csv_num = 1

    
    
for csv in sorted(os.listdir(transcripts_csv_3)):

    if '.csv' in csv:

        os.chdir(transcripts_csv_3)

        read = pd.read_csv(csv)

        os.chdir('../')

                
        
    for csv_1 in sorted(concat_p):

        #os.chdir('concat_p')

        if '.csv' in csv_1:

            os.chdir(concat_p)

            read1 = pd.read_csv(csv_1)

            os.chdir('../')

            

            #os.chdir('../')

        df = pd.concat([read, read1], axis=1)
        


        os.chdir('concat_p_transcript')

        df.to_csv(f'p{csv_num}.csv', sep=',', index=False)


        csv_num += 2

        os.chdir('../')
        
        break

# %%
# !ls
# Out:
# README.md            json                 transcripts_csv_2
# concat_p             preprocess_csv.ipynb transcripts_csv_3
# concat_p_transcript  test.csv
# emotion_annotations  transcripts_csv

# %%
csv_num = 1
for i in sorted(os.listdir('transcripts_csv_3')):
    
    #print(i)
    
    #if '.csv' in i:
    if i == 'p1.p2.m4a-20220330163422.csv':
        
        

        os.chdir('transcripts_csv_3')

        read = pd.read_csv(i)
        
        read["results/channelTag"] = pd.to_numeric(read["results/channelTag"], errors='coerce')
        
        os.chdir('../')

        #print(read)


        for j in sorted(os.listdir('concat_p')):

            if 'p1.p2_self.csv' in j:

                os.chdir('concat_p')

                read1 = pd.read_csv(j)

                os.chdir('../')

                #print(read1)

                #break
                
                df = pd.DataFrame()

                new_df = read1.iloc[:, 0:23]

                new2_df = read1.iloc[:, 23:]
                
                
                for k in read.iloc():
                    
                    for l in read1.iloc():
                        
                        if ((k[4] < l[0]).all() & (k != k[6].max()).all()):
                            
                            df = pd.concat([read, new_df], axis = 1)
                        
                        elif ((k[4] < l[23]).all() & (k == k[6].max()).all()):
                            
                            df = pd.concat([read, new2_df], axis = 1)
                            
                            
#         os.chdir('concat_p_transcript')
        
#         read.to_csv(f'p{csv_num}.csv', sep=',', index = False)
        
#         csv_num +=2
        
#         os.chdir('../')
                    
                
#                 for row in read['reult/alternative/0/word/0/tartTime']:


#                     for row2 in read1.iloc[:, 0]:

#                         for row3 in read1.iloc[:, 23]:


                                
#                             while ((row < row2) & (row < row3)):
                                


#                                 for i in read['results/channelTag']:
                                    
#                                     #print(i)

#                                     if i == 0:

#                                         pass

#                                     elif i < (read['results/channelTag'].max()):

#                                         df = pd.concat([read, new_df], axis = 1)

#                                     elif i == read['results/channelTag'].max():
#                                         #df = pd.merge(df, new2_df, how = 'outer', on = 'seconds' )
#                                         df.join(new2_df)
#                                     else:
#                                         pass

#         os.chdir('concat_p_transcript')             
#         df.to_csv(f'p{csv_num}.csv', sep=',', index=False)
#         csv_num += 2

#         os.chdir('../')
# Out:
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]
#       results/alternatives/0/confidence  \
# 0                              0.765099
# 1                              0.765099
# 2                              0.765099
# 3                              0.765099
# 4                              0.765099
# ...                                 ...
# 3448                           0.774450
# 3449                           0.481978
# 3450                           0.481978
# 3451                           0.481978
# 3452                           0.481978
#
#                       results/alternatives/0/transcript  \
# 0     all right first one the state for this accepti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3448                                                NaN
# 3449                                 Sprint is over now
# 3450                                                NaN
# 3451                                                NaN
# 3452                                                NaN
#
#       results/alternatives/0/words/0/confidence  \
# 0                                      0.912839
# 1                                      0.912839
# 2                                      0.912839
# 3                                      0.912839
# 4                                      0.912839
# ...                                         ...
# 3448                                   0.724903
# 3449                                   0.362569
# 3450                                   0.628419
# 3451                                   0.580469
# 3452                                   0.356456
#
#       reult/alternative/0/word/0/endTime  reult/alternative/0/word/0/tartTime  \
# 0                                    2.4                                  2.3
# 1                                    3.0                                  2.4
# 2                                    3.3                                  3.0
# 3                                    3.4                                  3.3
# 4                                    3.5                                  3.4
# ...                                  ...                                  ...
# 3448                               852.7                                852.4
# 3449                               851.6                                851.5
# 3450                               852.0                                851.6
# 3451                               852.4                                852.1
# 3452                               852.6                                852.4
#
#      results/alternatives/0/words/0/word  results/channelTag  \
# 0                                    all                 2.0
# 1                                  right                 2.0
# 2                                  first                 2.0
# 3                                    one                 2.0
# 4                                    the                 2.0
# ...                                  ...                 ...
# 3448                                 now                 0.0
# 3449                              Sprint                 0.0
# 3450                                  is                 0.0
# 3451                                over                 0.0
# 3452                                 now                 0.0
#
#      results/languageCode  reult/reultEndTime  seconds  ...  surprise  none_1  \
# 0                   en-us           25.888572      5.0  ...       NaN     NaN
# 1                   en-us           25.888572     10.0  ...       NaN     NaN
# 2                   en-us           25.888572     15.0  ...       NaN       x
# 3                   en-us           25.888572     20.0  ...       NaN       x
# 4                   en-us           25.888572     25.0  ...       NaN       x
# ...                   ...                 ...      ...  ...       ...     ...
# 3448                en-us          853.982100      NaN  ...       NaN     NaN
# 3449                en-us          854.002141      NaN  ...       NaN     NaN
# 3450                en-us          854.002141      NaN  ...       NaN     NaN
# 3451                en-us          854.002141      NaN  ...       NaN     NaN
# 3452                en-us          854.002141      NaN  ...       NaN     NaN
#
#       confrustion  contempt  dejection  disgust  eureka pride  sorrow none_2
# 0             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 1             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 2             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 3             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# 4             NaN       NaN        NaN      NaN     NaN   NaN     NaN      x
# ...           ...       ...        ...      ...     ...   ...     ...    ...
# 3448          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3449          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3450          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3451          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
# 3452          NaN       NaN        NaN      NaN     NaN   NaN     NaN    NaN
#
# [3453 rows x 32 columns]

# %%
for i in sorted(os.listdir('transcripts_csv_3')):

    if '.csv' in i:

        os.chdir('transcripts_csv_3')

        read = pd.read_csv(i)
        
        print(read.iloc[:, 4])
        
        os.chdir('../')

# %%
# !ls

# %%
df = pd.read_csv('transcripts_csv_3/p1.p2.m4a-20220330163422.csv')

# %%
for i in df.iloc():
    i[6] = pd.to_numeric(i[6], errors='coerce')
    print(i[6].max())
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# /Users/williamhan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/70/s03t_xm53wq9db1vxd6l5d8c0000gn/T/ipykernel_24458/2169787115.py in <module>
#       1 for i in df.iloc():
#       2     i[6] = pd.to_numeric(i[6], errors='coerce')
# ----> 3     print(i[6].max())
#
# AttributeError: 'float' object has no attribute 'max'

# %%
df["results/channelTag"] = pd.to_numeric(df["results/channelTag"], errors='coerce')

# %%
df['results/channelTag'].astype
