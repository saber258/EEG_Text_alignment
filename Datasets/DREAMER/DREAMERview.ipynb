# %%
import scipy
import scipy.io
import pandas as pd

# %%
# !ls
# Out:
# DREAMERview.ipynb

# %%
mat = scipy.io.loadmat('DREAMER.mat')

# %%
print(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Apr 13 17:20:26 2017', '__version__': '1.0', '__globals__': [], 'DREAMER': array([[(array([[array([[(array(['22'], dtype='<U2'), array(['male'], dtype='<U4'), array([[(array([[array([[4390.25641026, 4097.43589744, 4267.69230769, ..., 4512.30769231,
#                                                 4368.71794872, 4287.69230769],
#                                                [4397.43589744, 4095.8974359 , 4248.20512821, ..., 4506.15384615,
#                                                 4272.82051282, 4187.69230769],
#                                                [4391.79487179, 4091.28205128, 4261.02564103, ..., 4494.87179487,
#                                                 4342.56410256, 4256.41025641],
#                                                ...,
#                                                [4392.82051282, 4107.17948718, 4288.71794872, ..., 4532.82051282,
# ...

# %%
pd.read_csv('eeg_minmax_1_all')
# Out:
#      Unnamed: 0  psdtheta_1  psdalpha_1  psdbeta_1  psdtheta_2  psdalpha_2  \
# 0             0    0.013041    0.012126   0.005556    0.004563    0.004561
# 1             1    0.012897    0.011999   0.005521    0.003577    0.003578
# 2             2    0.013952    0.012973   0.005945    0.003262    0.003261
# 3             3    0.011079    0.010302   0.004722    0.003295    0.003294
# 4             4    0.015532    0.014442   0.006618    0.002610    0.002610
# ..          ...         ...         ...        ...         ...         ...
# 409         409    0.009454    0.008791   0.004030    0.002076    0.002133
# 410         410    0.012517    0.011641   0.005343    0.002604    0.002610
# 411         411    0.011613    0.010797   0.004949    0.006172    0.006719
# 412         412    0.005301    0.004929   0.002259    0.003789    0.004097
# 413         413    0.013848    0.012877   0.005904    0.000740    0.000800
#
# ...

# %%
pd.read_csv('ecg_minmax_1_all')
# Out:
#      Unnamed: 0  ECG_Rate_Mean  HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  \
# 0             0       0.635301    0.270729  0.225712         NaN         NaN
# 1             1       0.340549    0.555675  0.321562         NaN         NaN
# 2             2       0.669001    0.242236  0.279517         NaN         NaN
# 3             3       0.466721    0.424023  0.313782         NaN         NaN
# 4             4       0.745454    0.185582  0.134061         NaN         NaN
# ..          ...            ...         ...       ...         ...         ...
# 409         409       0.390411    0.503165  0.179045         NaN         NaN
# 410         410       0.742430    0.182856  0.176800         NaN         NaN
# 411         411       0.539819    0.355976  0.163908         NaN         NaN
# 412         412       0.496707    0.393215  0.149912         NaN         NaN
# 413         413       0.610246    0.293505  0.206605         NaN         NaN
#
# ...
